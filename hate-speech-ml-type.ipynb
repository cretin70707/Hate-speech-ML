# %% [markdown]
# #Dependencies

# %%
# pip install lime

# %%
# !pip install -q optuna

# %%
 # !pip install -q -U bnlp_toolkit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 55.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 42.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 44.1 MB/s eta 0:00:00
#   Building wheel for emoji (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.16.11 requires scipy>=1.11.2, but you have scipy 1.10.1 which is incompatible.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.4 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# scikit-image 0.25.0 requires scipy>=1.11.2, but you have scipy 1.10.1 which is incompatible.

# %%
# !gdown 1y6R4r2azEusl4bLyussZcZvo3-wI3dCn

# %%
# !pip install fasttext

# %%
import torch
import torch.nn as nn
import sklearn
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import fasttext
from bnlp import BasicTokenizer
from bnlp import SentencepieceTokenizer
from bnlp import BengaliWord2Vec
from bnlp import NLTKTokenizer
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
from transformers import BertTokenizer, BertForSequenceClassification, AdamW
from sklearn.metrics import precision_recall_fscore_support

# %%
df = pd.read_csv("/kaggle/input/hate-speech/dataset/train.csv")

# %% [markdown]
# #Cleaning

# %%
def clean_text(text):
    # Emoji removal pattern covering various emoji ranges
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"
                               u"\U0001F300-\U0001F5FF"
                               u"\U0001F680-\U0001F6FF"
                               u"\U0001F700-\U0001F77F"
                               u"\U0001F780-\U0001F7FF"
                               u"\U0001F800-\U0001F8FF"
                               u"\U0001F900-\U0001F9FF"
                               u"\U0001FA00-\U0001FA6F"
                               u"\U0001FA70-\U0001FAFF"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               "]+", flags=re.UNICODE)
    # Remove emojis
    text = emoji_pattern.sub(r'', text)
    # Remove English characters & numbers
    text = re.sub(r'[A-Za-z0-9]', '', text)
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    # Remove punctuation
    text = re.sub(r'[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]০১২৩৪৫৬৭৮৯', '', text)
    punctuations = '''`|¢|Ñ+-*/=EROero৳০১২৩৪৫৬৭৮৯012–34567•89।!()-[]{};:'"“\’,<>./?@#$%^&*_~‘—॥”‰🤣⚽️✌�￰৷￰'''
    # Create a character class to remove specified characters
    regex_pattern = '[' + re.escape(punctuations) + ']'
    text = re.sub(regex_pattern, '', text)


    return text

# %%
df['sentence'] = df['sentence'].apply(clean_text)

# %%
df = df.drop(columns=['hate speech','target'])

# %% [markdown]
# #Describe Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40224 entries, 0 to 40223
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  40224 non-null  object
#  1   type      19324 non-null  object
# dtypes: object(2)
# memory usage: 628.6+ KB

# %%
df.isnull().sum()
# Out:
# sentence        0
# type        20900
# dtype: int64

# %%
df.head()
# Out:
#                                             sentence            type
# 0                               ঐ ইন্দুর তোই মরছ নাই  callToViolence
# 1  গেবনের শেষে আইসা আপনার মুখোশ টা খুলছে এতেই আমি...  callToViolence
# 2                   মুরগি চোরের পাছায় ডুকবি আর মারবি  callToViolence
# 3   কোটির চোদা খাওয়া শেষে এখন কোটির চোদা খাবে মিথিলা  callToViolence
# 4                          য় মীর জাফরের মুখে মুতে দে  callToViolence

# %%
target_counts
# Out:
#                target  count
# 0                 ind   7057
# 1                male   5413
# 2              female   4093
# 3               group   2486
# 4         male_female    225
# 5        female_group     18
# 6          male_group     13
# 7          ind_female     10
# 8           ind_group      5
# 9   male_female_group      3
# 10           ind_male      1

# %%
import plotly.express as px

# Plot the distribution of 'target'
target_counts = df['type'].value_counts().reset_index()
target_counts.columns = ['type', 'count']  # Rename the columns for clarity

fig_target = px.bar(target_counts, 
                    x='type', 
                    y='count', 
                    labels={'type': 'Type', 'count': 'Count'},
                    title="Distribution of Type",
                    color='type', 
                    color_continuous_scale='Viridis')

# Use `fig.show()` to explicitly display the plot
fig_target.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c74eebdf-ecd0-49e0-9ade-1b6821fb5227" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c74eebdf-ecd0-49e0-9ade-1b6821fb5227")) {                    Plotly.newPlot(                        "c74eebdf-ecd0-49e0-9ade-1b6821fb5227",                        [{"alignmentgroup":"True","hovertemplate":"Type=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"slander","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"slander","offsetgroup":"slander","orientation":"v","showlegend":true,"textposition":"auto","x":["slander"],"xaxis":"x","y":[9814],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"callToViolence_slander","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"callToViolence_slander","offsetgroup":"callToViolence_slander","orientation":"v","showlegend":true,"textposition":"auto","x":["callToViolence_slander"],"xaxis":"x","y":[2914],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gender","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gender","offsetgroup":"gender","orientation":"v","showlegend":true,"textposition":"auto","x":["gender"],"xaxis":"x","y":[2376],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"callToViolence","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"callToViolence","offsetgroup":"callToViolence","orientation":"v","showlegend":true,"textposition":"auto","x":["callToViolence"],"xaxis":"x","y":[2020],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"religion","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"religion","offsetgroup":"religion","orientation":"v","showlegend":true,"textposition":"auto","x":["religion"],"xaxis":"x","y":[618],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"callToViolence_gender","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"callToViolence_gender","offsetgroup":"callToViolence_gender","orientation":"v","showlegend":true,"textposition":"auto","x":["callToViolence_gender"],"xaxis":"x","y":[487],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gender_slander","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"gender_slander","offsetgroup":"gender_slander","orientation":"v","showlegend":true,"textposition":"auto","x":["gender_slander"],"xaxis":"x","y":[374],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"religion_slander","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"religion_slander","offsetgroup":"religion_slander","orientation":"v","showlegend":true,"textposition":"auto","x":["religion_slander"],"xaxis":"x","y":[299],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"callToViolence_religion","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"callToViolence_religion","offsetgroup":"callToViolence_religion","orientation":"v","showlegend":true,"textposition":"auto","x":["callToViolence_religion"],"xax ...

# %%
df['type'].fillna('0', inplace=True) # Replace null values with 0
df.isnull().sum()
# Out:
# sentence    0
# type        0
# dtype: int64

# %%
type_unique = df['type'].nunique() # Number of unique classes
type_unique
# Out:
# 16

# %%
distinct_classes = df['type'].unique() # Get all unique classes
distinct_classes
# Out:
# array(['callToViolence', 'callToViolence_gender',
#        'callToViolence_religion', 'callToViolence_slander',
#        'callToViolence_religion_slander', 'slander', 'gender_slander',
#        'callToViolence_gender_slander', 'religion_slander', 'gender',
#        'callToViolence_gender_religion', 'gender_religion', 'religion',
#        'callToViolence_gender_religion_slander',
#        'gender_religion_slander', '0'], dtype=object)

# %%
class_mapping = {
    '0': 0,
    'callToViolence': 1,
    'callToViolence_gender': 2,
    'callToViolence_religion': 3,
    'callToViolence_slander': 4,
    'callToViolence_religion_slander': 5,
    'slander': 6,
    'gender_slander': 7,
    'callToViolence_gender_slander': 8,
    'religion_slander': 9,
    'gender': 10,
    'callToViolence_gender_religion': 11,
    'gender_religion': 12,
    'religion': 13,
    'callToViolence_gender_religion_slander': 14,
    'gender_religion_slander': 15
}

# Apply the mapping to the 'type' column
df['encoded_type'] = df['type'].map(class_mapping)

# Verify the encoding
df[['type', 'encoded_type']].head(50)
# Out:
#               type  encoded_type
# 0   callToViolence             1
# 1   callToViolence             1
# 2   callToViolence             1
# 3   callToViolence             1
# 4   callToViolence             1
# 5   callToViolence             1
# 6   callToViolence             1
# 7   callToViolence             1
# 8   callToViolence             1
# 9   callToViolence             1
# 10  callToViolence             1
# 11  callToViolence             1
# 12  callToViolence             1
# 13  callToViolence             1
# 14  callToViolence             1
# 15  callToViolence             1
# 16  callToViolence             1
# 17  callToViolence             1
# 18  callToViolence             1
# 19  callToViolence             1
# 20  callToViolence             1
# 21  callToViolence             1
# 22  callToViolence             1
# 23  callToViolence             1
# 24  callToViolence             1
# 25  callToViolence             1
# 26  callToViolence             1
# 27  callToViolence             1
# 28  callToViolence             1
# 29  callToViolence             1
# 30  callToViolence             1
# 31  callToViolence             1
# 32  callToViolence             1
# 33  callToViolence             1
# 34  callToViolence             1
# 35  callToViolence             1
# 36  callToViolence             1
# 37  callToViolence             1
# 38  callToViolence             1
# 39  callToViolence             1
# 40  callToViolence             1
# 41  callToViolence             1
# 42  callToViolence             1
# 43  callToViolence             1
# 44  callToViolence             1
# 45  callToViolence             1
# 46  callToViolence             1
# 47  callToViolence             1
# 48  callToViolence             1
# 49  callToViolence             1

# %%
distinct_classes = df['type'].unique()
distinct_classes
# Out:
# array(['callToViolence', 'callToViolence_gender',
#        'callToViolence_religion', 'callToViolence_slander',
#        'callToViolence_religion_slander', 'slander', 'gender_slander',
#        'callToViolence_gender_slander', 'religion_slander', 'gender',
#        'callToViolence_gender_religion', 'gender_religion', 'religion',
#        'callToViolence_gender_religion_slander',
#        'gender_religion_slander', '0'], dtype=object)

# %%
print(df['sentence'].iloc[2],"\n")
print(df['sentence'].iloc[4],"\n")
# Out:
# মুরগি চোরের পাছায় ডুকবি আর মারবি
#
# য় মীর জাফরের মুখে মুতে দে

# %%
word_counts = df['sentence'].apply(lambda x: len(x.split()))

plt.figure(figsize=(10, 6))
plt.hist(word_counts, bins=20, color='orange', alpha=0.9)
plt.title('Distribution of comment length')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()

# %% [markdown]
# #Tokenization

# %% [markdown]
# Tokenize

# %%
basic_tokenizer = BasicTokenizer()

df['sentence'] = df['sentence'].apply(basic_tokenizer.tokenize)

# %%
df.head(50)
# Out:
#     index                                           sentence  target  \
# 0       0                               ঐ ইন্দুর তোই মরছ নাই     ind
# 1       1  গেবনের শেষে আইসা আপনার মুখোশ টা খুলছে এতেই আমি...     ind
# 2       2                   মুরগি চোরের পাছায় ডুকবি আর মারবি     ind
# 3       3   কোটির চোদা খাওয়া শেষে এখন কোটির চোদা খাবে মিথিলা  female
# 4       4                          য় মীর জাফরের মুখে মুতে দে    male
# 5       5  অই কখানকি সত্যি বলতে কি জানছ তরে জুদি পাইতাম ত...  female
# 6       6  অই জারছি পরা লোক টা কে পাইলে কোত্তার মতো পিটাইতাম     ind
# 7       7   অকে পিথিবির আলো দেখানোর আগেই মেরে ফেলা দরকার ছিল     ind
# 8       8                                 অকে মেরে ফেলতে হবে     ind
# 9       9                             অগরে চুদে মেয়ে গূলোকে   group
# 10     10  অগুনে পুড়িয়ে মারা হওক যাতে আর কেউ এমনটা করার স...     ind
# 11     11                    অদের কে জুতা দিয়ে পিঢাও না কেনো     ind
# 12     12  অনেক দিন ধরেই অপেক্ষা করতেছিলাম এই ভন্ডটারে ধই...     ind
# 13     13  অ‌নেক ভাই ক‌রে‌ছেন যে লোপাকে চুদ‌তে চাই তা‌দে...  female
# 14     14  অপু আদরের ছেলেকে বাবার মত ইসলাম ধর্ম গ্রহণ করত...    male
# 15     15  অপু উকিল এর পুটকির মধ্যে কেরোসিন ঢেলে দেওয়া উচিত  female
# 16     16                    অপু উকিল কে আমি পুটকি মারতে ছাই  female
# 17     17         অপু উকিল তুই তো ভোট চোর তোর মুখে লাথি মারী  female
# 18     18  অপু উকিল তোর বোদার বিতর কন্সিওয়ালা বাঁশ ডুকানো...  female
# 19     19               অপু উকিলের শাউয়াদিয়া মানকছুদেওয়া হোক  female
# 20     20     অপু একটি মিথ্যাচার করছে ওকে জুতা পেটা করা উচিত  female
# 21     21                            অপু কলকাতা গিয়ে চুদা খা  female
# 22     22                                    অপু কে জুতা মার  female
# 23     23                     অপু কে পেলে জুতা পেটা করা উচিত  female
# 24     24                                অপু খারাব জুতা মারি  female
# 25     25                                      অপু চুদা খাভে  female
# 26     26                                  অপু তোকে আমি চুদি  female
# 27     27                                  অপু তোর মুকে মুতি  female
# 28     28                             অপু মরলে আরো খুশি আমরা  female
# 29     29                                 অপুকে মদ খায়ানু হক  female
# 30     30  অপুর অপরাত সে তার পায়ের জুতো খুলে কেন শাকিবকে ...  female
# 31     31     অপুরে জুতা মারা লাকবে এখন অপু বক্ত কেউ থাকবেনা  female
# 32     32           অমিত শাহ্ র দুই গালে জোতা মারো তালে তালে    male
# 33     33                               অমিত সাহ কে বাঁশ দেও    male
# 34     34                           অর ছেলে একদিন অকেই মারবে     ind
# 35     35                           অর দুই হাত কেটে ফেলা হোক     ind
# 36     36                                 অর নুনুটা কেটে ফেল    male
# 37     37                               অর বাঁচার অধিকার নাই     ind
# 38     38      অর বুদার মধ্যে কারেন্ট দিলে সব এমনিই বলে দিবে  female
# 39     39  অর মত ছেলে জন্ম নেয়ার আগে মুখে লবন দিয়া কেউ মা...     ind
# 40     40       অর যাওয়ার দরকার নাই সবাই মিলে চুদে পুশে দেবো  female
# 41     41                              অর সোনা কেটে নেয়া হউক     ind
# 42     42                                   অর হাত কাটা উচিত     ind
# 43     43                          অর হাত দুটি কেটে ফেলা হোক     ind
# 44     44                অরে জুতার মালা পরান উচিতসালা বেদ্দপ     ind
# 45     45  অরে টা জোতোর বাড়ি দেয়াহোক ভিড়িও দারন কারীকে ধন...     ind
# 46     46                     অরে ডায়রেক ক্রসফায়ার দেওক দিয়া     ind
# 47     47          অরে পাইলে আমি শেষ করে ফেলতাম যা হবার হইতো     ind
# 48     48                              অরে মদ খাওয়া তারাতারি     ind
# 49     49                                        অরে মাইরালা     ind
#
#     encoded_target
# 0                1
# 1                1
# 2                1
# 3                2
# 4                3
# 5                2
# 6                1
# 7                1
# 8                1
# 9                4
# 10               1
# 11               1
# 12               1
# 13               2
# 14               3
# 15               2
# 16               2
# 17               2
# 18               2
# 19               2
# 20               2
# 21               2
# 22               2
# 23               2
# 24               2
# 25               2
# 26               2
# 27               2
# 28               2
# 29               2
# 30               2
# 31               2
# 32               3
# 33               3
# 34               1
# 35               1
# 36               3
# 37               1
# 38               2
# 39               1
# 40               2
# 41               1
# 42               1
# 43               1
# 44               1
# 45               1
# 46               1
# 47               1
# 48               1
# 49               1

# %% [markdown]
# Tf-idf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

df['sentence'] = df['sentence'].apply(lambda x: ' '.join(x))  # Join tokens into a single string

# Apply TfidfVectorizer with unigram and bigram
tfidf_bigram = TfidfVectorizer(ngram_range=(1, 2), use_idf=True, tokenizer=lambda x: x.split())

# Apply TF-IDF to the joined (space-separated) text data
x_tfidf_bigram = tfidf_bigram.fit_transform(df['sentence'])

# If you have labels in 'hate speech' column
X_train, X_test, y_train, y_test = train_test_split(x_tfidf_bigram, df['type'], test_size=0.2, random_state=42)

# %% [markdown]
# Evaluator

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import RocCurveDisplay
from sklearn.preprocessing import label_binarize

def evaluate_model(model, X_test, y_test):
    # Model type display
    print(70*'-')
    print(f"Evaluating model: {model.__class__.__name__}")
    
    # Predict the results
    y_pred = model.predict(X_test)
    
    # For multiclass, we use label_binarize to get binary relevance for each class
    class_labels = ['0', 'callToViolence', 'callToViolence_gender', 'callToViolence_religion', 
                    'callToViolence_slander', 'callToViolence_religion_slander', 'slander', 
                    'gender_slander', 'callToViolence_gender_slander', 'religion_slander', 
                    'gender', 'callToViolence_gender_religion', 'gender_religion', 
                    'religion', 'callToViolence_gender_religion_slander', 'gender_religion_slander']

    # Binarize the true and predicted labels for multiclass
    y_test_bin = label_binarize(y_test, classes=class_labels)
    y_pred_bin = label_binarize(y_pred, classes=class_labels)

    # Compute accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='macro')  # or 'micro' or 'weighted'
    recall = recall_score(y_test, y_pred, average='macro')  # or 'micro' or 'weighted'
    f1 = f1_score(y_test, y_pred, average='macro')  # or 'micro' or 'weighted'
    
    # Print evaluation metrics
    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision (macro): {precision:.4f}')
    print(f'Recall (macro): {recall:.4f}')
    print(f'F1 Score (macro): {f1:.4f}')
    
    # Generate the confusion matrix for multiclass
    cm = confusion_matrix(y_test, y_pred)

    # Plotting the confusion matrix
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.show()

    # ROC Curve and AUC for multiclass classification (one-vs-rest approach)
    fpr, tpr, roc_auc = {}, {}, {}
    for i in range(len(class_labels)):
        fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_bin[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    
    # Plot ROC curve for each class
    plt.figure(figsize=(12, 10))
    for i in range(len(class_labels)):
        plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {class_labels[i]} (AUC = {roc_auc[i]:.4f})')
    
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()
    
    print(70*'-')

# %% [markdown]
# Train & evaluate

# %% [markdown]
# random forest

# %%
model_rf = RandomForestClassifier(random_state=42 )
model_rf.fit(X_train, y_train)
evaluate_model(model_rf, X_test, y_test)
# Out:
# ----------------------------------------------------------------------
# Evaluating model: RandomForestClassifier
# Accuracy: 0.7115
# Precision (macro): 0.3638
# Recall (macro): 0.1806
# F1 Score (macro): 0.2042
# ----------------------------------------------------------------------

# %% [markdown]
# logistic regression

# %%
model_lr = LogisticRegression(penalty='l2',random_state=0)
model_lr.fit(X_train, y_train)
evaluate_model(model_lr, X_test, y_test)
# Out:
# ----------------------------------------------------------------------
# Evaluating model: LogisticRegression
# Accuracy: 0.7027
# Precision (macro): 0.3747
# Recall (macro): 0.1694
# F1 Score (macro): 0.1922
# ----------------------------------------------------------------------

# %% [markdown]
# knn

# %%
model_knn = KNeighborsClassifier(n_neighbors=5, weights='uniform')
model_knn.fit(X_train, y_train)
evaluate_model(model_knn, X_test, y_test)
# Out:
# ----------------------------------------------------------------------
# Evaluating model: KNeighborsClassifier
# Accuracy: 0.5195
# Precision (macro): 0.2324
# Recall (macro): 0.0665
# F1 Score (macro): 0.0505
# ----------------------------------------------------------------------

# %% [markdown]
# svm
